# %% [markdown]
# <a href="https://colab.research.google.com/github/LiRay7/sal-rab-homeworks/blob/master/%D0%94%D0%971.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""Задание 1.
Даны 2 переменных, в которых хранятся строки произвольной длины: phrase_1 и phrase_2.
Напишите код, который проверяет какая из этих строк длиннее."""

phrase_1 = 'Насколько проще было бы писать программы, если бы не заказчики'
phrase_2 = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
if len(phrase_1) > len(phrase_2):
    print ('phrase_1 длиннее phrase_2')
elif len(phrase_1) == len(phrase_2):
    print ('Фразы одинаковой длины')
else: print('phrase_2 длиннее phrase_1')

# В задании странные результаты показаны, вероятно, предполагалось, что я буду использовать только одно условие и ставить <=/>=, но по логике это не очень правильно, если фразы равны, писать, что одна длиннее. поэтому сделала как выше.
# Out:
# phrase_1 длиннее phrase_2

# %%
"""Задание 2
Дана переменная, в которой хранится число (год). Необходимо написать программу, которая выведет, является ли данный год високосным или обычным."""

Year = int(input('Введите год: '))
if Year % 400 == 0:
  print (Year, '- Високосный год')
elif Year % 100 != 0 and Year % 4 == 0:
  print (Year, '- Високосный год')
else: print (Year, '- Обычный год')

#правило определение для Григорианского календаря взяла из Википедии, есть вероятность, что будут дополнительные нюансы, не стала в этом копаться)))
# Out:
# Введите год1900
# 1900 - Обычный год

# %%
"""
Задание 3
Необходимо написать программу, которая будет запрашивать у пользователя месяц и дату рождения и выводить соответствующий знак зодиака."""

Month = (input('Введите месяц рождения: ')).capitalize
Day = input('Введите дату рождения: ')
if Month == 'Январь' and Day <=20:
    print('Ваш знак зодиака: Козерог')
elif Month == 'Январь' and Day > 20:
    print('Ваш знак зодиака: Водолей')
elif Month == 'Февраль'and Day <=20:
    print('Ваш знак зодиака: Водолей')
elif Month == 'Февраль'and Day >20:
    print('Ваш знак зодиака: Рыбы')
elif Month == 'Март'and Day <= 20:
    print('Ваш знак зодиака: Рыбы')
elif Month == 'Март'and Day >20:
    print('Ваш знак зодиака: Овен')
elif Month == 'Апрель'and Day <= 20:
    print('Ваш знак зодиака: Овен')
elif Month == 'Апрель'and Day >20:
    print('Ваш знак зодиака: Телец')
elif Month == 'Май'and Day <= 20:
    print('Ваш знак зодиака: Телец')
elif Month == 'Май'and Day >20:
    print('Ваш знак зодиака: Близнецы')
elif Month == 'Июнь'and Day <= 21:
    print('Ваш знак зодиака: Близнецы')
elif Month == 'Июнь'and Day >21:
    print('Ваш знак зодиака: Рак')
elif Month == 'Июль'and Day <= 22:
    print('Ваш знак зодиака: Рак')
elif Month == 'Июль'and Day >22:
    print('Ваш знак зодиака: Лев')
elif Month == 'Август'and Day <= 23:
    print('Ваш знак зодиака: Лев')
elif Month == 'Август'and Day >23:
    print('Ваш знак зодиака: Дева')
elif Month == 'Сентябрь'and Day <= 24:
    print('Ваш знак зодиака: Дева')
elif Month == 'Сентябрь'and Day >24:
    print('Ваш знак зодиака: Весы')
elif Month == 'Октябрь'and Day <= 23:
    print('Ваш знак зодиака: Весы')
elif Month == 'Октябрь'and Day >23:
    print('Ваш знак зодиака: Скорпион')
elif Month == 'Ноябрь'and Day <= 22:
    print('Ваш знак зодиака: Скорпион')
elif Month == 'Ноябрь'and Day >22:
    print('Ваш знак зодиака: Стрелец')
elif Month == 'Декабрь'and Day <= 21:
    print('Ваш знак зодиака: Стрелец')
elif Month == 'Декабрь'and Day >21:
    print('Ваш знак зодиака: Козерог')
else:
    print('Ошибка! некорректный ввод')
# Out:
# Введите месяц рождениямай
# Введите дату рождения10
# Ошибка! некорректный ввод

# %%
"""мне так не понравилось писать громадину выше, что я сделала задачу по анаолгии с тем, как я бы сделала в sql.
сперва хотела взять массив, но почитала, что в Питоне массивы - это сложно, а строки - это местный "аналог". результат выдается адекватный, вроде, все правильно."""


month_list = ['январь', 'февраль', 'март', 'апрель', 'май', 'июнь', 'июль', 'август', 'сентябрь', 'октябрь', 'ноябрь', 'декабрь']
Zod_list = ['Козерог', 'Водолей', 'Рыбы', 'Овен', 'Телец', 'Близнецы', 'Рак', 'Лев', 'Дева', 'Весы', 'Скорпион', 'Стрелец']
zod_day = [21, 21, 21, 21, 21, 22, 23, 24, 24, 24, 23, 22]
Month = input('Введите месяц рождения: ')
Day = int(input('Введите дату рождения: '))
a = month_list.index(Month)
if Month not in month_list or Day >=31:
  print('Ошибка! некорректный ввод')
elif Day < int(zod_day[a]):
  print('Ваш знак зодиака:', Zod_list[a])
else: print('Ваш знак зодиака:', Zod_list[a+1])

#Вопрос 1. Как обходить проблему с регистром? если я хочу, чтобы было все равно, как вводят значение: с большой или с маленькой?
#я пыталась сделать: Month = input('Введите месяц рождения').lower, но выдается ошибка. надо доп. переменную тогда вводить?

#Вопрос 2. Есть ли какая-то стандартная проверка на дату? в идеале мне бы тут запрашивать сразу дату рождения и вытаскивать месяц аналогом datetrunc, чтобы уже его сравнивать со списком... чтобы нельзя было ввести 30.02...
# Out:
# Введите месяц рождениямай
# Введите дату рождения24
# Ваш знак зодиака: Близнецы

# %%
"""Задание 4
Вам нужно написать программу для подбора упаковок по размерам товара. Размеры (ширина, длина, высота) хранятся в переменных (в сантиметрах):

Используйте следующие правила:

если каждое из трех измерений менее или равно 15 сантиметрам, то выведите на экран "Коробка №1";
если хотя бы одно из измерений больше 2 метров, то выводите "Упаковка для лыж";
если хотя бы одно из измерений больше 15 сантиметров, но менее 50 сантиметров, то выводите "Коробка №2";
во всех остальных случаях выводите "Коробка №3"."""

Width = int(input('Введите ширину товара в сантиметрах: '))
Length = int(input('Введите длину товара в сантиметрах: '))
Height = int(input('Введите высоту товара в сантиметрах: '))
if Width <= 15 and Length <= 15 and Height <= 15:
  print('Коробка №1')
elif Width > 200 or Length > 200 or Height > 200:
  print('Упаковка для лыж')
elif (Width > 15 and Width < 50) or (Length > 15 and Length < 50) or (Height > 15 and Height < 50):
  print('Коробка №2')10
else: print('Коробка №3')
# Out:
# Введите ширину товара в сантиметрах100
# Введите длину товара в сантиметрах0
# Введите высоту товара в сантиметрах100
# Коробка №3

# %%
"""Задание 5 (необязательное)
Дана переменная, в которой хранится шестизначное число (номер проездного билета).
Напишите программу, которая будет определять, является ли данный билет "счастливым".
Билет считается счастливым, если сумма первых трех цифр совпадает с суммой последних трех цифр номера."""

Luckynum = str(input('Введите номер билета: '))
if len(Luckynum) == 6:
    if int(Luckynum[0]) + int(Luckynum[1]) + int(Luckynum[2]) == int(Luckynum[3]) + int(Luckynum[4]) + int(Luckynum[5]                                                                                                                    ):
      print('Счастливый билет')
    else: print('Несчастливый билет')
else: print('Введен некорректный номер')
# Out:
# Введите номер билета5544666
# Введен некорректный номер

# %%
"""Задание 6 (необязательное)
Напишите программу, которая сможет вычислять площади трех фигур (круг, треугольник и прямоугольник). Тип фигуры запрашиваем через пользовательский ввод, после чего делаем запрос характеристик фигуры:

если пользователь выбрал круг, запрашиваем его радиус,
если треугольник – длины трех его сторон;
если прямоугольник – длины двух его сторон."""

import math
Figure = input('Введите тип фигуры: ')
if Figure == 'круг':
  Raduis = float(input('Введите радиус в см: '))
  print('Площадь равна', (math.pi*(Raduis**2)), 'см2')
elif Figure == 'треугольник':
   SideA = float(input('Введите длину первой стороны в см: '))
   SideB = float(input('Введите длину второй стороны в см: '))
   SideC = float(input('Введите длину третьей стороны в см: '))
   p = (SideA + SideB + SideC)/ 2
   print('Площадь равна',(math.sqrt(p*(p-SideA)*(p-SideB)*(p-SideC))), 'см2')
elif Figure == 'прямоугольник':
   SideA = float(input('Введите длину первой стороны в см: '))
   SideB = float(input('Введите длину второй стороны в см: '))
   print('Площадь равна', (SideA*SideB), 'см2')
else: print('Тип фигуры не поддерживается')
# Out:
# Введите тип фигуры: круг
